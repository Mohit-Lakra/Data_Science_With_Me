# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib Basics

# %%
x = np.linspace(0,15,10)
y = x**2
x
# Out:
# array([ 0.        ,  1.66666667,  3.33333333,  5.        ,  6.66666667,
#         8.33333333, 10.        , 11.66666667, 13.33333333, 15.        ])

# %%
y
# Out:
# array([  0.        ,   2.77777778,  11.11111111,  25.        ,
#         44.44444444,  69.44444444, 100.        , 136.11111111,
#        177.77777778, 225.        ])

# %%
plt.plot(x,y)
plt.title("Square Graph")
plt.xlabel("x")
plt.ylabel("x_square")
# Out:
# Text(0, 0.5, 'x_square')

# %% [markdown]
# ## Subplots in matlplotlib

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(x**2,y)
plt.subplot(2,2,4)
plt.plot(y**2,x)

# %% [markdown]
# ## Object Oriented Way

# %%
fig = plt.figure(figsize = (4,4), dpi = 200)
axis1 = fig.add_axes([0.1,0.1,0.9,0.9])
axis1.plot(x,y)
axis2 = fig.add_axes([0.4,0.5,0.2,0.2])
axis2.plot(y,x)

# %% [markdown]
# ## Types of plot

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([12.,  7.,  8.,  9.,  6.,  9., 16., 15.,  6., 12.]),
#  array([  6. , 104.6, 203.2, 301.8, 400.4, 499. , 597.6, 696.2, 794.8,
#         893.4, 992. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1120f7a10>,
#   <matplotlib.lines.Line2D at 0x1120f7b60>],
#  'caps': [<matplotlib.lines.Line2D at 0x1120f7cb0>,
#   <matplotlib.lines.Line2D at 0x1120f7e00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1120f78c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11215c050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11215c1a0>],
#  'means': []}

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("Basic Plot")

# %% [markdown]
# ## Working with images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('Image.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1279.5), np.float64(738.5), np.float64(-0.5))

# %%
crop = img[50:200, 100:300]
plt.imshow(crop)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# # Optional Designing

# %%
plt.plot(x,y,color='green')

# %%
fig, ax = plt.subplots(figsize=(12,6))
xaxis = np.linspace(1,10,10)

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestyle options '--', '-.', ':', 'steps'
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='--')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50])  # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+9,  color="blue", lw=3, ls='--', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='--', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
